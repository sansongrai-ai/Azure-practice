# %%
# %sql
create table emp(id int, name string);
insert into emp values(1,'abc'),(2,'xyz');
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th><th>num_inserted_rows</th></tr></thead><tbody><tr><td>2</td><td>2</td></tr></tbody></table></div>

# %%
df = spark.readStream.format("delta").table("emp")

# %%
checkpoint_path = "/Volumes/klrdatabrick3/default/klrvolume/checkpoint/6"
output_path = "/Volumes/klrdatabrick3/default/klrvolume/output11"

# %%
import uuid
def foreach_batch_function(df, epoch_id):
    #array_id = df.collect()[0][0]
    #if array_id == 3:
        #raise Exception("Test Exception")
 
    df.write.mode("append").json(output_path + "/" +str(uuid.uuid4()))
 
 
query = (df.writeStream.foreachBatch(foreach_batch_function).option("checkpointLocation", checkpoint_path).start())

# %%
# %sql

insert into emp values(2,'abc'),(3,'xyz');
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th><th>num_inserted_rows</th></tr></thead><tbody><tr><td>2</td><td>2</td></tr></tbody></table></div>

# %%
# %fs
ls /Volumes/klrdatabrick3/default/klrvolume/output11
# Out:
# com.databricks.backend.common.rpc.CommandCancelledException
# 	at com.databricks.spark.chauffeur.SequenceExecutionState.$anonfun$cancel$5(SequenceExecutionState.scala:132)
# 	at scala.Option.getOrElse(Option.scala:201)
# 	at com.databricks.spark.chauffeur.SequenceExecutionState.$anonfun$cancel$3(SequenceExecutionState.scala:132)
# 	at com.databricks.spark.chauffeur.SequenceExecutionState.$anonfun$cancel$3$adapted(SequenceExecutionState.scala:129)
# 	at scala.collection.immutable.Range.foreach(Range.scala:190)
# 	at com.databricks.spark.chauffeur.SequenceExecutionState.cancel(SequenceExecutionState.scala:129)
# 	at com.databricks.spark.chauffeur.ExecContextState.cancelRunningSequence(ExecContextState.scala:715)
# 	at com.databricks.spark.chauffeur.ExecContextState.$anonfun$cancel$1(ExecContextState.scala:435)
# 	at scala.Option.getOrElse(Option.scala:201)
# 	at com.databricks.spark.chauffeur.ExecContextState.cancel(ExecContextState.scala:435)
# ...

# %%
# %fs
ls dbfs:/Volumes/klrdatabrick3/default/klrvolume/output11/5f5a6cbd-8806-48c4-84d0-4507f3ca4ee4/
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
# %fs
head dbfs:/Volumes/klrdatabrick3/default/klrvolume/output11/5f5a6cbd-8806-48c4-84d0-4507f3ca4ee4/part-00000-tid-4164484719081801515-0e475e00-16a5-4f5c-b184-d37efbe63adb-2-1-c000.json
# Out:
# {"id":1,"name":"abc"}
# {"id":2,"name":"xyz"}

# %%
# %sql
insert into emp values(3,'abc'),(4,'xyz');
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th><th>num_inserted_rows</th></tr></thead><tbody><tr><td>2</td><td>2</td></tr></tbody></table></div>
